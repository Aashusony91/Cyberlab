# %% [markdown]
# Load data

# %%
import numpy as np
import pandas as pd

# df = pd.read_csv("kmeans_data.csv")   # example file
# X = df.values

# %%
# Standardize (important for K-Means)
X = (X - np.mean(X, axis=0)) / np.std(X, axis=0)

# %% [markdown]
# Distance function

# %%
def euclidean_distance(x1, x2):
    return np.sqrt(np.sum((x1 - x2) ** 2))

# %%
def assign_clusters(X, centroids):
    clusters = []

    for x in X:
        distances = [euclidean_distance(x, c) for c in centroids]
        clusters.append(np.argmin(distances))

    return np.array(clusters)

# %%
def update_centroids(X, clusters, K):
    new_centroids = []

    for k in range(K):
        cluster_points = X[clusters == k]
        new_centroids.append(np.mean(cluster_points, axis=0))

    return np.array(new_centroids)

# %%
def kmeans(X, K, max_iters=100):
    m, n = X.shape

    # Initialize centroids (first K points – no randomness)
    centroids = X[:K]

    for _ in range(max_iters):
        clusters = assign_clusters(X, centroids)
        new_centroids = update_centroids(X, clusters, K)

        # Convergence check
        if np.allclose(centroids, new_centroids):
            break

        centroids = new_centroids

    return centroids, clusters

# %%
K = 3
centroids, clusters = kmeans(X, K)

print("Centroids:\n", centroids)
print("Cluster assignments:\n", clusters)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 K = 3
# ----> 2 centroids, clusters = kmeans(X, K)
#       4 print("Centroids:\n", centroids)
#       5 print("Cluster assignments:\n", clusters)
#
# NameError: name 'X' is not defined
